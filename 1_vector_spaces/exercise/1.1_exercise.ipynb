# %% [markdown]
# Convention: $0$ means the zero element in a field. $\mathit{0}$ means the zero vector in a vector space.

# %% [markdown]
# ## 1. Let $V$ be a vector space. Using the properties of VS 1 through VS 8, show that if $c$ is a number, then $c \mathit{0} = \mathit{0}$.

# %% [markdown]
# ### Proof
#
# $$
# \begin{array}{l}
# c \mathit{0} &= \mathit{0} \\
# &= c (\mathit{0} + \mathit{0}) &\text{VS 2} \\
# &= c \mathit{0} + c \mathit{0} &\text{VS 5} \\
# c \mathit{0} + (- (c \mathit{0})) &= (c \mathit{0} + c \mathit{0}) + (- (c \mathit{0})) \\
# \underbrace{\mathit{0}}_{\text{VS 3}} &= \underbrace{c \mathit{0} + (c \mathit{0} + (- (c \mathit{0})))}_{\text{VS 1}} \\
# \mathit{0} &= c \mathit{0} + \underbrace{\mathit{0}}_{\text{VS 3}} \\
# \mathit{0} &= \underbrace{c \mathit{0}}_{\text{VS 2}} \\
# c \mathit{0} &= \mathit{0}
# \end{array}
# $$ Q.E.D.

# %% [markdown]
# ## 2. Let $c$ be a number $\neq 0$, and $v$ an element of $V$. Prove that if $c v = \mathit{0}$, then $v = \mathit{0}$.

# %% [markdown]
# ### Proof
#
# $$
# \begin{array}{l}
# c v &= \mathit{0} \\
# c v + \mathit{0} &= \mathit{0} &\text{VS 2} \\
# c v + c v &= \mathit{0} \\
# \underbrace{c (v + v)}_{\text{VS 5}} &= \mathit{0} \\
# \underbrace{c^{-1}}_{\text{exists in the field as $c \neq 0$}} (c (v + v)) &= c^{-1} \mathit{0} \\
# \underbrace{(c^{-1} c) (v + v)}_{\text{VS 7}} &= \underbrace{\mathit{0}}_{\text{conclusion of ex 1}} \\
# 1 (v + v) &= \mathit{0} \\
# \underbrace{v + v}_{\text{VS 8}} &= \mathit{0} \\
# (- v) + (v + v) &= (- v) + \mathit{0} \\
# \underbrace{((- v) + v) + v}_{\text{VS 1}} &= \underbrace{\mathit{0}}_{\text{VS 2}} \\
# \underbrace{(v + (- v))}_{\text{VS 4}} + v &= \underbrace{\mathit{0}}_{\text{VS 2}} \\
# \underbrace{\mathit{0}}_{\text{VS 3}} + v &= \mathit{0} \\
# \underbrace{v}_{\text{VS 2}} &= \mathit{0} \\
# \end{array}
# $$ Q.E.D.

# %% [markdown]
# ## 3. In the vector space of functions, what is the function satisfying VS 2?

# %% [markdown]
# ### Solution
#
# Let's denote the vector space of functions $f: S \to K$ as $V$, where $K$ is a field.
#
# Let's denote the zero element of $K$ as $0$.
#
# Let's denote the zero vector of $V$ as $\mathit{0}$.
#
# Let's define function $\mathit{0} \in V$, such that
# $$\mathit{0}(x) = 0$$
#
# For $f \in V$, we have $$
# \begin{array}{l}
# (\mathit{0} + f) (x) &= \mathit{0}(x) + f(x) &\text{Definition of addition in space of functions} \\
# &= 0 + f(x) \\
# &= f(x) + 0 &\text{Associativity of field $K$} \\
# &= f(x) + \mathit{0}(x) \\
# &= (f + \mathit{0}) (x)
# \end{array}
# $$. Hence VS 2 is satisfied.

# %% [markdown]
# ### 4. Let $V$ be a vector space, and $v, w$ two elements of $V$. If $v + w = \mathit{0}$, show that $w = - v$.

# %% [markdown]
# ### Proof
#
# $$
# \begin{array}{l}
# v + w &= \mathit{0} \\
# (- v) + (v + w) &= (- v) + \mathit{0} \\
# \underbrace{(- v + v) + w}_{\text{VS 1}} &= \underbrace{- v}_{\text{VS 2}} \\
# \underbrace{(v + (- v))}_{\text{VS 4}} + w &= \underbrace{- v}_{\text{VS 2}} \\
# \underbrace{\mathit{0}}_{\text{VS 3}} + w &= - v \\
# \underbrace{w}_{\text{VS 2}} &= - v
# \end{array}
# $$ Q.E.D.

# %% [markdown]
# ## 5. Let $V$ be a vector space, and $v, w$ two elements of $V$ such that $v + w = v$. Show that $w = 0$.

# %% [markdown]
# ### Proof
#
# $$
# \begin{array}{l}
# v + w &= v \\
# (- v) + (v + w) &= (- v) + v \\
# \underbrace{((- v) + v) + w}_{\text{VS 1}} &= \underbrace{v + (- v)}_{\text{VS 4}} \\
# (\underbrace{(v + (- v)}_{\text{VS 4}}) + w &= \underbrace{\mathit{0}}_{\text{VS 3}} \\
# \underbrace{\mathit{0}}_{\text{VS 3}} + w &= \mathit{0} \\
# \underbrace{w}_{\text{VS 2}} &= \mathit{0}
# \end{array}
# $$ Q.E.D.

# %% [markdown]
# ## 6. Let $A_1, A_2$ be vectors in $R^n$. Show that the set of all vectors $B$ in $R^n$ such that $B$ is perpendicular to both $A_1$ and $A_2$ is a subspace.

# %% [markdown]
# ### Proof
#
# Let's define $V$ such that $V \subseteq R^n$, and each of its element is perpendicular to both $A_1$ and $A_2$.
#
# By the definition of subspaces, to prove $V$ is a subspace of $R^n$, we need to prove
#
# - (i) For $B_1, B_2 \in V$, $B_1 + B_2 \in V$ also holds.
# - (ii) For $c \in R$ and $B \in V$, $c B \in V$ also holds.
# - (iii) Let $\mathit{0}$ be the zero vector of $R^n$ ($\mathit{0} = (\underbrace{0, ..., 0}_{n})$). $\mathit{0} \in V$ also holds.
#
# To prove (i):
#
# Let $B_1, B_2 \in V$. Since $B_1, B_2$ are perpendicular to both $A_1$ and $A_2$, we have
# $$
# \begin{array}{l}
# A_1 \cdot (B_1 + B_2) &= \underbrace{A_1 \cdot B_1 + A_1 \cdot B_2}_{\text{$A_1, B_1, B_2 \in R^n$, $R$ is a field, so SP 2 holds}} \\
# &= \underbrace{0}_{\text{$B_1$ is perpendicular to $A_1$}} + \underbrace{0}_{\text{$B_2$ is perpendicular to $A_1$}} \\
# &= \underbrace{0}_{\text{Additive identity of $R$}}
# \end{array}
# $$ Hence $B_1 + B_2$ is perpendicular to $A_1$.
#
# Similarly, we can prove $B_1 + B_2$ is perpendicular to $A_2$.
#
# Hence (i) is satisfied.
#
# To prove (ii):
#
# Let $B \in V$, and $c \in R$. Then we have
# $$
# \begin{array}{l}
# A_1 \cdot (c B) &= c(A_1 \cdot B) &\text{SP 3} \\
# &= c \underbrace{0}_{\text{$B$ is perpendicular to $A_1$}} \\
# &= 0
# \end{array}
# $$. Similarly, we can prove $A_2 \cdot (c B) = 0$.
#
# Hence (ii) is satisfied.
#
# To prove (iii):
#
# $$
# A_1 \cdot \mathit{0} = 0
# $$ and $$
# A_2 \cdot \mathit{0} = 0
# $$. Hence $\mathit{0} \in V$, by the definition of $V$.
#
# Hence (iii) is satisfied.
#
# Hence $V$ is a subspace of $R^n$. Q.E.D.

# %% [markdown]
# ## 7. Generalize Exercise 6, and prove: Let $A_1, ..., A_r$ be vectors in $R^n$. Let $W$ be the set of vectors $B$ in $R^n$ such that $B \cdot A_i = 0$ for every $i = 1, ..., r$. Show that $W$ is a subspace of $R^n$.

# %% [markdown]
# ### Proof:
#
# By the definition of subspaces, to prove $W$ is a subspace of $R^n$, we need to prove
#
# - (i) For $B_1, B_2 \in W$, $B_1 + B_2 \in W$ also holds.
# - (ii) For $c \in R$ and $B \in W$, $c B \in W$ also holds.
# - (iii) Let $\mathit{0}$ be the zero vector of $R^n$ ($\mathit{0} = (\underbrace{0, ..., 0}_{n})$). $\mathit{0} \in V$ also holds.
#
# To prove (i):
#
# For $i = 1, ..., r$:
#
#  * Let $B_1, B_2 \in W$. We have
#
# $$
# \begin{array}{l}
# A_i \cdot (B_1 + B_2) &= \underbrace{A_i \cdot B_1 + A_i \cdot B_2}_{\text{$A_i, B_1, B_2 \in R^n$, $R$ is a field, so SP 2 holds}} \\
# &= \underbrace{0}_{B_i \in W} + \underbrace{0}_{B_2 \in W} \\
# &= \underbrace{0}_{\text{Additive identity of $R$}}
# \end{array}
# $$
#  * Hence $B_1 + B_2 \in W$ for $B_1, B_2 \in W$.
#
# Hence (i) is satisfied.
#
# To prove (ii):
#
# For $i = 1, ..., r$:
#
#  * Let $B \in W$, and $c \in R$. Then we have
#
# $$
# \begin{array}{l}
# A_i \cdot (c B) &= c(A_i \cdot B) &\text{SP 3} \\
# &= c \underbrace{0}_{\text{$B \in W$}} \\
# &= 0
# \end{array}
# $$
#
# Hence (ii) is satisfied.
#
# To prove (iii):
#
# For $i = 1, ..., r$:
#
# $$
# A_i \cdot \mathit{0} = 0
# $$
#
# Hence $\mathit{0} \in W$, by the definition of $W$.
#
# Hence (iii) is satisfied.
#
# Hence $W$ is a subspace of $R^n$. Q.E.D.

# %% [markdown]
# ### 8. Show that the following sets of elements in $R^2$ form subspaces
#
# - (a) The set of all $(x, y)$ such that $x = y$.
# - (b) The set of all $(x, y)$ such that $x - y = 0$.
# - (c) The set of all $(x, y)$ such that $x + 4 y = 0$.

# %% [markdown]
# ### Proof
#
# #### (a) The set of all $(x, y)$ such that $x = y$.
#
# Let's denote the set of all $(x, y)$ such that $x = y$ as $V$.
#
# (i):
#
# Let $v, w \in V$. By the definition of $V$, we can denote $v = (x_1, x_1)$ and $w = (x_2, x_2)$.
#
# Then we have
# $$
# (x_1, x_1) + (x_2, x_2) = (x_1 + x_2, x_1 + x_2)
# $$. Hence we have shown $v + w \in V$.
#
# (ii):
#
# Let $v \in V$. By the definition of $V$, we can denote $v = (x, x)$.
#
# Let $c \in R$.
#
# Then we have $$
# c (x, x) = (c x, c x)
# $$. Hence we have shown $c x \in V$.
#
# (iii):
#
# The zero vector in $R^2$ is $\mathit{0} = (0, 0)$. Hence $\mathit{0} \in V$ by the definition of $V$.
#
# Hence the set of all $(x, y)$ such that $x = y$ is a subspace of $R^n$.
#
# #### (b) The set of all $(x, y)$ such that $x - y = 0$.
#
# $x - y = 0$ is identical to $x = y$. As (a) is proven, (b) is proven.
#
# Hence the set of all $(x, y)$ such that $x - y = 0$ is a subspace of $R^n$.
#
# #### (c) The set of all $(x, y)$ such that  $x + 4 y = 0$.
#
# Let's denote the set of all $(x, y)$ such that $x + 4 y = 0$ as $V$.
#
# (i):
#
# Let $v, w \in V$. By the definition of $V$, we can denote $v = (x_1, - \frac{1}{4} x_1)$ and $w = (x_2, - \frac{1}{4} x_2)$.
#
# Then we have
# $$
# (x_1, - \frac{1}{4} x_1) + (x_2, - \frac{1}{4} x_2) = (x_1 + x_2, - \frac{1}{4} (x_1 + x_2))
# $$. Hence we have shown $v + w \in V$.
#
# (ii):
#
# Let $v \in V$. By the definition of $V$, we can denote $v = (x, -\frac{1}{4} x)$.
#
# Let $c \in R$.
#
# Then we have $$
# c (x, - \frac{1}{4} x) = (c x, -\frac{1}{4} (c x))
# $$. Hence we have shown $c x \in V$.
#
# (iii):
#
# The zero vector in $R^2$ is $\mathit{0} = (0, 0) = (0, - \frac{1}{4} \cdot 0)$. Hence $\mathit{0} \in V$ by the definition of $V$.
#
# Hence the set of all $(x, y)$ such that $x + 4 y = 0$ is a subspace of $R^2$.
#
# Q.E.D.

# %% [markdown]
# ## 9. Show that the following sets of elements in $R^3$ form subspaces.
#
# - (a) The set of all $(x,y,z)$ such that $x + y + z = 0$.
# - (b) The set of all $(x,y,z)$ such that $x = y$ and $2 y = z$.
# - (c) The set of all $(x,y,z)$ such that $x + y = 3 z$.

# %% [markdown]
# ### Proof
#
# #### (a) The set of all $(x,y,z)$ such that $x + y + z = 0$.
#
# Let's denote the set of all $(x, y, z)$ such that $x + y + z = 0$ as $V$.
#
# (i):
#
# Let $v, w \in V$. We can denote $v = (x_1, y_1, z_1)$ and $w = (x_2, y_2, z_2)$.
#
# Then we have
# $$
# v + w = (x_1 + x_2, y_1 + y_2, z_1 + z_2)
# $$.
#
# Then we know that $$
# \begin{equation}
# \begin{aligned}
# (x_1 + x_2) + (y_1 + y_2) + (z_1 + z_2) &= (x_1 + y_1 + z_1) + (x_2 + y_2 + z_2) \\
# &= 0 + 0 \\
# &= 0
# \end{aligned}
# \end{equation}
# $$. Hence $v + w \in V$.
#
# (ii):
#
# Let $v \in V$. We can denote $v = (x, y, z)$.
#
# Let $c \in R$.
#
# Then we have $$
# c v = (c x, c y, c z)
# $$. Then we have $$
# \begin{equation}
# \begin{aligned}
# c x + c y + c z &= c (x + y + z) \\
# &= c \cdot 0 \\
# &= 0
# \end{aligned}
# \end{equation}
# $$. Hence $c v \in V$.
#
# (iii):
#
# The zero vector in $R^3$ is $\mathit{0} = (0, 0, 0)$. Since $0 + 0 + 0 = 0$, $\mathit{0} \in V$ by the definition of $V$.
#
# Hence the set of all $(x, y, z)$ such that $x + y + z = 0$ is a subspace of $R^3$.
#
# #### (b) The set of all $(x,y,z)$ such that $x = y$ and $2 y = z$.
#
# Let's denote the set of all $(x, y, z)$ such that $x = y$ and $2 y = z$ as $V$.
#
# (i):
#
# Let $v, w \in V$. We can denote $v = (x_1, y_1, z_1)$ and $w = (x_2, y_2, z_2)$.
#
# Then we have
# $$
# v + w = (x_1 + x_2, y_1 + y_2, z_1 + z_2)
# $$.
#
# Then we know that $$
# \begin{array}{l}
# x_1 &= y_1 \\
# x_2 &= y_2 \\
# \end{array}
# $$. Hence $x_1 + x_2 = y_1 + y_2$. Also $$
# \begin{array}{l}
# 2 y_1 &= 2 z_1 \\
# 2 y_2 &= 2 z_2 \\
# \end{array}
# $$. Hence $2 (y_1 + y_2) = 2 (z_1 + z_2)$.
#
# Hence $v + w \in V$.
#
# (ii):
#
# Let $v \in V$. We can denote $v = (x, y, z)$.
#
# Let $c \in R$.
#
# Then we have $$
# c v = (c x, c y, c z)
# $$. Then we have $$
# \begin{array}{l}
# c x &= c y \\
# 2 (c y) &= c z \\
# \end{array}
# $$. Hence $c v \in V$.
#
# (iii):
#
# The zero vector in $R^3$ is $\mathit{0} = (0, 0, 0)$. Since $0 = 0$ and $2 \cdot 0 = 0$, $\mathit{0} \in V$.
#
# Hence the set of all $(x, y, z)$ such that $x = y$ and $2 y = z$ is a subspace of $R^3$.
#
# #### (c) The set of all $(x,y,z)$ such that $x + y = 3 z$
#
# Skip

# %% [markdown]
# ## 10. If $U, W$ are subspaces of a vector space $V$, show that $U \cap W$ and $U + W$ are subspaces.

# %% [markdown]
# ### Proof
#
# #### $U \cap W$:
#
# (i):
#
# Let $u, v \in (U \cap W)$. Then $u \in U$ and $v \in U$, and $u \in W$ and $v \in W$.
#
# Since both $U$ and $W$ are subspaces of $V$, then $(u + v) \in U$ and $(u + v) \in W$.
#
# Hence $(u + v) \in (U \cap W)$.
#
# (ii):
#
# Let $u \in (U \cap W)$. Then $u \in U$ and $u \in W$.
#
# Let $K$ be the field under $V$. Let $c \in K$.
#
# Since both $U$ and $W$ are subspaces of $V$, then $c u \in U$ and $c u \in W$.
#
# Hence $c u \in (U \cap W)$.
#
# (iii):
#
# Since both $U$ and $W$ are subspaces of $V$, then $\mathit{0} \in U$ and $\mathit{0} \in W$.
#
# Hence $\mathit{0} \in (U \cap W)$.
#
# Hence $U \cap W$ is a subspace of $V$.
#
# #### For $U + W$:
#
# (i):
#
# Let $a, b \in (U + W)$. Then we can denote $a$ as $a = u_a + v_a$ and $b = u_b + v_b$, where $u_a, u_b \in U$ and $v_a, v_b \in W$.
#
# Then
# $$
# \begin{equation}
# \begin{aligned}
# a + b &= (u_a + v_a) + (u_b + v_b) \\
# &= \underbrace{(u_a + u_b)}_{\in U} + \underbrace{(v_a + v_b)}_{\in W} & \text{As $U$ and $W$ are subspace of $V$ and VS 1 applies to $V$}
# \end{aligned}
# \end{equation}
# $$
#
# Hence $(a + b) \in (U + W)$.
#
# Let $a \in (U + W)$. Then we can denote $a$ as $a = u_a + v_a$.
#
# Let $K$ be the field under $V$. Let $c \in K$.
#
# Since both $U$ and $W$ are subspaces of $V$, then $c u_a \in U$ and $c u_a \in W$.
#
# Then
# $$
# \begin{equation}
# \begin{aligned}
# c a &= c (u_a + v_a) \\
# &= \underbrace{c u_a}_{\in U} + \underbrace{c v_a}_{\in W} &\text{VS 5 of $V$}
# \end{aligned}
# \end{equation}
# $$
#
# Hence $c a \in (U + W)$.
#
# (iii):
#
# Since both $U$ and $W$ are subspaces of $V$, then $\mathit{0} \in U$ and $\mathit{0} \in W$.
#
# Then
# $$
# \begin{equation}
# \begin{aligned}
# \mathit{0} &= \underbrace{\mathit{0}}_{\in U} + \underbrace{\mathit{0}}_{\in W} & \text{VS 2} \\
# \end{aligned}
# \end{equation}
# $$
#
# Hence $\mathit{0} \in (U + W)$.
#
# Hence $U + W$ is a subspace of $V$.
#
# Q.E.D.

# %% [markdown]
# ## 11. Let $K$ be a subfield of a field $L$. Show that $L$ is a vector space over $K$. In particular, $C$ and $R$ are vector spaces over $Q$.

# %% [markdown]
# ### Proof
#
# First, let's show $L$ is a vector space.
#
# - VS 1: $L$ is a subset of $C$, so VS 1 holds from additive associativity of $C$.
# - VS 2: holds by the property (c) of a field.
# - VS 3: holds by the property (b) of a field.
# - VS 4: holds by from additive commutativity $C$.
# - VS 5: holds by distributivity of $C$.
# - VS 6: holds by additive commutativity and distributivity of $C$ combined.
# - VS 7: holds by multiplicative associativity of $C$.
# - VS 8: holds by the property (c) of a field.
#
# As $K$ is subfield of $L$, $K \subseteq L$.
#
# (i):
#
# Let $x, y \in K$.
#
# By the property (a) of field, $(x + y) \in K$.
#
# (ii):
#
# Let $c, x \in K$.
#
# By the property (a) of field, $c x \in K$.
#
# (iii):
#
# By the property (c) of field, $\mathit{0} = 0$ exists in $K$.

# %% [markdown]
# ## 12. Let $K$ be the set of all numbers which can be written in the form $a + b \sqrt{2}$, where $a, b$ are rational numbers. Show that $K$ is a field.

# %% [markdown]
# ### Proof
#
# Property (a):
#
# Let $x, y \in K$. We can denote $x = a_x + b_x \sqrt{2}$, and $y = a_y + b_y \sqrt{2}$, where $a_x, b_x, a_y, b_y \in Q$.
#
# Then
# $$
# \begin{equation}
# \begin{aligned}
# x + y &= (a_x + b_x \sqrt{2}) + (a_y + b_y \sqrt{2}) \\
# &= \underbrace{(a x + a_y)}_{\in Q} + \underbrace{(b_x + b_y)}_{\in Q} \sqrt{2} &\text{Algebraic properties of $Q$}
# \end{aligned}
# \end{equation}
# $$
#
# Hence $(x + y) \in K$.
#
# And also
# $$
# \begin{equation}
# \begin{aligned}
# x y &= (a_x + b_x \sqrt{2}) (a_y + b_y \sqrt{2}) \\
# &= a_x a_y + a_x b_y \sqrt{2} + a_y  b_x \sqrt{2} + 2 b_x b_y \\
# &= \underbrace{(a_x a_y + 2 b_x b_y)}_{\in Q} + \underbrace{(a_x b_y + a_y b_x)}_{\in Q} \sqrt{2}
# \end{aligned}
# \end{equation}
# $$
#
# Property (b):
#
# Let $x \in K$. Then
# $$
# \begin{equation}
# \begin{aligned}
# - x &= - (a + b \sqrt{2}) \\
# &= \underbrace{(- a)}_{\in Q} + \underbrace{(- b)}_{\in Q} \sqrt{2} \\
# \end{aligned}
# \end{equation}
# $$
#
# Hence $(- x) \in K$.
#
# Also, for $x \neq 0$
#
# $$
# \begin{equation}
# \begin{aligned}
# x^{-1} &= \frac{1}{a + b \sqrt{2}} \\
# &= \frac{a - b \sqrt{2}}{a^2 + 2 b^2} & \text{$x \neq 0 \implies a, b \neq 0 \implies a^2 + 2 b^2 \neq 0$} \\
# &= \underbrace{\frac{a}{a^2 + 2 b^2}}_{\in Q} + \underbrace{(- \frac{b}{a^2 + 2 b^2})}_{\in Q} \sqrt{2}
# \end{aligned}
# \end{equation}
# $$
#
# Hence $x^{-1} \in K$.
#
#
# Property (c):
# $$
# \begin{equation}
# \begin{aligned}
# 1 &= 1 + 0 \cdot \sqrt{2}
# \end{aligned}
# \end{equation}
# $$
#
# and
# $$
# \begin{equation}
# \begin{aligned}
# 0 &= 0 + 0 \cdot \sqrt{2}
# \end{aligned}
# \end{equation}
# $$
#
# Hence $1 \in K$ and $0 \in K$.
#
# Hence $K$ is a field. Q.E.D.

# %% [markdown]
# ## 13. Let $K$ be the set of all numbers which can be written in the form $a + bi$, where $a, b$ are rational numbers. Show that $K$ is a field.

# %% [markdown]
# Skip.

# %% [markdown]
# ## 14. Let $c$ be a rational number $> 0$, and let $\gamma$ be a real number such that $\gamma^2 = c$. Show that the set of all numbers which can be written in the form $a + b \gamma$, where $a, b$ are rational numbers, is a field.

# %% [markdown]
# ### Proof
#
# Let $K$ be the set of numbers that can be written in the form $a + b \gamma$.
#
# Property (a):
#
# Let $x, y \in K$. Then we can denote $x = a_x + b_x \gamma$, and $y = a_y + b_y \gamma$, where $a_x, b_x, a_y, b_y \in Q$.
#
# Then
# $$
# \begin{equation}
# \begin{aligned}
# x + y &= (a_x + b_x \gamma) + (a_y + b_y \gamma) \\
# &= \underbrace{(a_x + a_y)}_{\in Q} + \underbrace{(b_x + b_y)}_{\in Q} \gamma &\text{Algebraic properties of $R$}
# \end{aligned}
# \end{equation}
# $$
#
# Hence $(x + y) \in K$.
#
# And also
# $$
# \begin{equation}
# \begin{aligned}
# x y &= (a_x + b_x \gamma) (a_y + b_y \gamma) \\
# &= a_x a_y + a_x b_y \gamma + a_y b_x \gamma + b_x b_y \gamma^2 &\text{Algebraic properties of Q} \\
# &= \underbrace{(a_x a_y + c b_x b_y)}_{\in Q} + \underbrace{(a_x b_y + a_y b_x)}_{\in Q} \gamma
# \end{aligned}
# \end{equation}
# $$
#
# Hence $(x y) \in K$.
#
# Property (b):
#
# Let $x \in K$, we can denote $x = a_x + b_x \gamma$.
#
# Then
# $$
# \begin{equation}
# \begin{aligned}
# - x &= - a_x + b_x \gamma \\
# &= \underbrace{- a_x}_{\in Q} + \underbrace{(- b_x)}_{\in Q} \gamma
# \end{aligned}
# \end{equation}
# $$
#
# Hence $(- x) \in K$.
#
# And also for $x \neq 0$
# $$
# \begin{equation}
# \begin{aligned}
# x^{-1} &= \frac{1}{a_x + b_x \gamma} \\
# &= \frac{a_x - b_x \gamma}{a_x^2 + b_x^2 \gamma^2} \\
# &= \frac{a_x - b_x \gamma}{a_x^2 + c b_x^2} \\
# &= \underbrace{\frac{a_x}{a_x^2 + c b_x^2}}_{\in Q} + \underbrace{(- \frac{b_x}{a_x^2 + c b_x^2})}_{\in Q} \gamma
# \end{aligned}
# \end{equation}
# $$
#
# Hence $x^{-1} \in K$.
#
# (c)
#
# $$
# \begin{equation}
# \begin{aligned}
# 1 &= \underbrace{1}_{\in Q} + \underbrace{0}_{\in Q} \cdot \gamma
# \end{aligned}
# \end{equation}
# $$
#
# Hence $1 \in K$.
#
# $$
# \begin{equation}
# \begin{aligned}
# 0 &= \underbrace{0}_{\in Q} + \underbrace{0}_{\in Q} \cdot \gamma
# \end{aligned}
# \end{equation}
# $$
#
# Hence $0 \in K$.
#
# Q.E.D.
